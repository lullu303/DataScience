# %%
#드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')

#현재 작업 위치 이동
#띄어쓰기에 \붙일 것
# %cd /content/drive/Othercomputers/내\ 노트북_before/Devpy/14.딥러닝
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/Othercomputers/내 노트북_before/Devpy/14.딥러닝

# %% [markdown]
# # 사전모델 활용
#
# ResNet50모델 사용
#
# https://www.tensorflow.org/api_docs/python/tf/keras/applications/resnet50/ResNet50

# %% [markdown]
# ## 코끼리 분류하기

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions

# %%
#모델 다운 ResNet50

# %%
#샘플 이미지 로드

# %% [markdown]
# > * ImageNet의 클래스 종류 :
# https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt

# %% [markdown]
# ----

# %% [markdown]
# ## 자전거 분류하기

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions

# %%
# ResNet50 모델 사용
model = ResNet50(weights='imagenet')

# %% [markdown]
# ---

# %% [markdown]
# # 사전학습 모델 + 전이학습
#
# * 분류하고자 하는 이미지가 없을 경우
# * 컨볼루션 층은 그대로 사용하고, FNN층은 목적에 맞게 재구성해서 학습시킴.

# %% [markdown]
# 텐스플로 데이터 세트 https://www.tensorflow.org/datasets/catalog/tf_flowers

# %% [markdown]
# >

# %% [markdown]
# ## 딥러닝 구성
